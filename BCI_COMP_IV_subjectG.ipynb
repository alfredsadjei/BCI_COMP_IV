# %%
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import scipy
import ipynb.fs
import pandas as pd

from ipynb.fs.defs.BCI_COMP_IV_functions import (extractInfo, featureExtraction, createFilterBank,
                                                testWindowLength, testClassifier, testFrequencyBand,
                                                testWindowStartTime,testWindowStartTime_Length, startRunningClassifier,
                                                tuneModelHyperParams)

# %%
dataG = scipy.io.loadmat("BCICIV_1calib_1000Hz_mat/BCICIV_calib_ds1g_1000Hz.mat")

dataG["cnt"] = 0.1 * dataG["cnt"].astype(float)

eeg = dataG["cnt"].T
nChannels, nSamples = eeg.shape

motionIntentComp, idleStateComp = [1,-3], [3,-2]

calibDataStore, testData_motionIntent, _, = featureExtraction(dataG,0.7, motionIntentComp, idleStateComp)

calibData_idle_motionIntent, testData_idle_motionIntent, W_idle_motionIntent = featureExtraction(dataG,0.7, motionIntentComp, idleStateComp,ExtractionType="idle_motionIntent")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ### Base Classifiers for detecting Idle State (no resampling)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score,cross_val_predict
from sklearn.metrics import roc_curve, auc, accuracy_score


ldaModel = LDA()
SVMmodel = SVC(probability=True,class_weight="balanced")
logRegModel = LogisticRegression(class_weight="balanced")

# %%
nCols = len(calibData_idle_motionIntent.columns)

print("Cross Validation Score")
print("-----------------------")
print("LDA: ",np.mean(cross_val_score(ldaModel,calibData_idle_motionIntent.iloc[:,:nCols-1], calibData_idle_motionIntent.iloc[:,nCols-1],cv=5)))
print("Logistic Regression: ",np.mean(cross_val_score(logRegModel,calibData_idle_motionIntent.iloc[:,:nCols-1], calibData_idle_motionIntent.iloc[:,nCols-1],cv=5)))
print("SVM: ",np.mean(cross_val_score(SVMmodel,calibData_idle_motionIntent.iloc[:,:nCols-1], calibData_idle_motionIntent.iloc[:,nCols-1],cv=5)))
print()
# Out:
# Cross Validation Score
# -----------------------
# LDA:  0.6357142857142858
# Logistic Regression:  0.6321428571428571
# SVM:  0.6214285714285713

# %% [markdown]
# ### Tuned Classifiers for detecting Idle State (no resampling)

# %%
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')

# %%
bestMods = tuneModelHyperParams(calibData_idle_motionIntent.iloc[:,:nCols-1], calibData_idle_motionIntent.iloc[:,nCols-1],testData_idle_motionIntent.iloc[:,:nCols-1], testData_idle_motionIntent.iloc[:,nCols-1])
bestMods
# Out:
# defaultdict(dict,
#             {'accuracy': {'SVC': (SVC(C=10, class_weight='balanced', gamma=0.01, probability=True),
#                0.5833333333333334),
#               'LogReg': (LogisticRegression(C=14.563484775012444, class_weight='balanced', penalty='l1',
#                                   solver='liblinear'),
#                0.6083333333333333),
#               'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'),
#                0.5916666666666667)},
#              'roc_auc': {'SVC': (SVC(C=1000, class_weight='balanced', gamma=0.01, probability=True),
#                0.5833333333333334),
#               'LogReg': (LogisticRegression(C=0.3727593720314938, solver='liblinear'),
#                0.5833333333333334),
#               'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'),
#                0.5916666666666667)},
#              'f1': {'SVC': (SVC(C=1, gamma=0.01, probability=True), 0.475),
#               'LogReg': (LogisticRegression(C=0.012648552168552958, class_weight='balanced',
#                                   solver='liblinear'),
#                0.575),
#               'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'),
#                0.5916666666666667)}})

# %%
bestModel, bestPerformance = None, 0

for metric in bestMods:
    for model in bestMods[metric]:
        mod, perf = bestMods[metric][model]

        if perf > bestPerformance:
            bestModel, bestPerformance = mod, perf

# %%
print(bestModel, bestPerformance)
# Out:
# LogisticRegression(C=14.563484775012444, class_weight='balanced', penalty='l1',
#                    solver='liblinear') 0.6083333333333333

# %%
idlesStateClassifier = bestModel

# %% [markdown]
# ### Base Classifier for classifying motion intent signals

# %%
ldaModel = LDA()
SVMmodel = SVC(probability=True)
logRegModel = LogisticRegression()

# %%
for name, calibData in calibDataStore.items():

    nCols = len(calibData.columns)
    print(name,end="\n")
    print("-----------")

    print("LDA: ",np.mean(cross_val_score(ldaModel,calibData.iloc[:,:nCols-1], calibData.iloc[:,nCols-1],cv=5)))
    print("Logistic Regression: ",np.mean(cross_val_score(logRegModel,calibData.iloc[:,:nCols-1], calibData.iloc[:,nCols-1],cv=5)))
    print("SVM: ",np.mean(cross_val_score(SVMmodel,calibData.iloc[:,:nCols-1], calibData.iloc[:,nCols-1],cv=5)))
    print()
# Out:
# RO
# -----------
# LDA:  0.9502463054187192
# Logistic Regression:  0.9571428571428571
# SVM:  0.9293103448275861
#
# SMOTE
# -----------
# LDA:  0.9573891625615764
# Logistic Regression:  0.9571428571428571
# SVM:  0.9362068965517242
#
# RU
# -----------
# LDA:  0.9484126984126984
# Logistic Regression:  0.9489417989417991
# SVM:  0.912962962962963
#
# CC
# -----------
# LDA:  0.942063492063492
# Logistic Regression:  0.9563492063492065
# SVM:  0.9134920634920636
#
# None
# -----------
# LDA:  0.9571428571428571
# Logistic Regression:  0.9571428571428571
# SVM:  0.9428571428571428

# %% [markdown]
# ### Tuned Classifiers for detecting motion intent signals

# %%
for name, calibData in calibDataStore.items():

    bestMods = tuneModelHyperParams(calibData.iloc[:,:nCols-1],
                                    calibData.iloc[:,nCols-1],
                                    testData_motionIntent.iloc[:,:nCols-1],
                                    testData_motionIntent.iloc[:,nCols-1])

    bestModel, bestPerformance = None, 0

    for metric in bestMods:
        for model in bestMods[metric]:
            mod, perf = bestMods[metric][model]

            if perf > bestPerformance:
                bestMetric, bestModel, bestPerformance = metric, mod, perf

    print(name)
    print("-------")
    print(f"Model = {bestModel}, Performance = {bestPerformance}, Metric = {bestMetric} ")
    print()
    print(f"All metrics = {bestMods}")
    print()
# Out:
# RO
# -------
# Model = SVC(C=1, gamma=0.1, probability=True), Performance = 0.8666666666666667, Metric = accuracy
#
# All metrics = defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=1, gamma=0.1, probability=True), 0.8666666666666667), 'LogReg': (LogisticRegression(C=0.001, class_weight='balanced', solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.4, solver='lsqr'), 0.8666666666666667)}, 'roc_auc': {'SVC': (SVC(C=0.0001, class_weight='balanced', gamma=1, probability=True), 0.85), 'LogReg': (LogisticRegression(C=0.002329951810515372, class_weight='balanced',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.7000000000000001, solver='lsqr'), 0.85)}, 'f1': {'SVC': (SVC(C=100, class_weight='balanced', gamma=0.1, probability=True), 0.8166666666666667), 'LogReg': (LogisticRegression(C=0.001, class_weight='balanced', solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.4, solver='lsqr'), 0.8666666666666667)}})
#
# SMOTE
# -------
# Model = LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), Performance = 0.8666666666666667, Metric = accuracy
#
# All metrics = defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=100, class_weight='balanced', gamma=1, kernel='linear', probability=True), 0.8333333333333334), 'LogReg': (LogisticRegression(C=0.001, class_weight='balanced', solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.8666666666666667)}, 'roc_auc': {'SVC': (SVC(C=0.0001, class_weight='balanced', gamma=1, probability=True), 0.8666666666666667), 'LogReg': (LogisticRegression(C=0.002329951810515372, class_weight='balanced',
#                    solver='liblinear'), 0.85), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.9, solver='lsqr'), 0.8666666666666667)}, 'f1': {'SVC': (SVC(C=100, class_weight='balanced', gamma=1, kernel='linear', probability=True), 0.8333333333333334), 'LogReg': (LogisticRegression(C=0.28117686979742307, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.6000000000000001, solver='lsqr'), 0.8666666666666667)}})
#
# RU
# -------
# Model = LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), Performance = 0.8666666666666667, Metric = accuracy
#
# All metrics = defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=1000, class_weight='balanced', gamma=0.0001, probability=True), 0.8166666666666667), 'LogReg': (LogisticRegression(C=0.49417133613238334, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.8666666666666667)}, 'roc_auc': {'SVC': (SVC(C=0.0001, class_weight='balanced', gamma=1, probability=True), 0.85), 'LogReg': (LogisticRegression(C=0.004094915062380427, class_weight='balanced',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.8666666666666667)}, 'f1': {'SVC': (SVC(C=1000, class_weight='balanced', gamma=0.0001, probability=True), 0.8166666666666667), 'LogReg': (LogisticRegression(C=0.49417133613238334, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.8666666666666667)}})
#
# CC
# -------
# Model = LinearDiscriminantAnalysis(shrinkage=0.4, solver='lsqr'), Performance = 0.8666666666666667, Metric = roc_auc
#
# All metrics = defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=1, class_weight='balanced', gamma=1, kernel='linear', probability=True), 0.8333333333333334), 'LogReg': (LogisticRegression(C=0.15998587196060574, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.8, solver='lsqr'), 0.85)}, 'roc_auc': {'SVC': (SVC(C=100, class_weight='balanced', gamma=0.1, probability=True), 0.8166666666666667), 'LogReg': (LogisticRegression(C=0.3727593720314938, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.4, solver='lsqr'), 0.8666666666666667)}, 'f1': {'SVC': (SVC(C=1, class_weight='balanced', gamma=1, kernel='linear', probability=True), 0.8333333333333334), 'LogReg': (LogisticRegression(C=0.15998587196060574, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.8, solver='lsqr'), 0.85)}})
#
# None
# -------
# Model = LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), Performance = 0.8666666666666667, Metric = accuracy
#
# All metrics = defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=10, class_weight='balanced', gamma=0.01, probability=True), 0.8333333333333334), 'LogReg': (LogisticRegression(C=0.0017575106248547913, class_weight='balanced',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.8666666666666667)}, 'roc_auc': {'SVC': (SVC(C=0.0001, class_weight='balanced', gamma=0.1, probability=True), 0.5166666666666667), 'LogReg': (LogisticRegression(C=0.0013257113655901094, class_weight='balanced',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.9, solver='lsqr'), 0.8333333333333334)}, 'f1': {'SVC': (SVC(C=10, class_weight='balanced', gamma=0.01, probability=True), 0.8333333333333334), 'LogReg': (LogisticRegression(C=0.0017575106248547913, class_weight='balanced',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.6000000000000001, solver='lsqr'), 0.85)}})

# %% [markdown]
# ### Window Start time test

# %% [markdown]
# #### Accuracy

# %%
# bestEstimator_start_time = testWindowStartTime(dataG,
#                     ["Logistic Regression","LDA","SVC"],
#                     "accuracy",
#                     0.7,
#                     2.0)

# %% [markdown]
# ### Investigating the effect of varying the frquency band (for each resampling technique)

# %%
channelNames,sRate,classLabels,eventOnsets,eventCodes,labels = extractInfo(dataG,nSamples)

filterBank = createFilterBank(sRate)

freqBandEstimators = {}

# %%
for resamplerType in calibDataStore.keys():
    print(resamplerType)
    print("------------")
    bestBand, bestEstimator_freq_band, (best_b, best_a), W_freq_band = testFrequencyBand(dataG,
                                                                                         filterBank,
                                                                                         0.7,
                                                                                         motionIntentComp,
                                                                                         idleStateComp,
                                                                                         trialWinStart=0,
                                                                                         trialWinEnd = 4,
                                                                                         resampler=resamplerType)

    print()

    freqBandEstimators[resamplerType] = (bestBand, bestEstimator_freq_band, (best_b, best_a), W_freq_band)
# Out:
# RO
# ------------
# 8-12 : 0.8666666666666667 (accuracy)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=1, gamma=0.1, probability=True), 0.8666666666666667), 'LogReg': (LogisticRegression(C=0.001, class_weight='balanced', solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.4, solver='lsqr'), 0.8666666666666667)}, 'roc_auc': {'SVC': (SVC(C=0.0001, class_weight='balanced', gamma=1, probability=True), 0.85), 'LogReg': (LogisticRegression(C=0.002329951810515372, class_weight='balanced',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.7000000000000001, solver='lsqr'), 0.85)}, 'f1': {'SVC': (SVC(C=100, class_weight='balanced', gamma=0.1, probability=True), 0.8166666666666667), 'LogReg': (LogisticRegression(C=0.001, class_weight='balanced', solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.4, solver='lsqr'), 0.8666666666666667)}})
# ************************
# 8-15 : 0.8 (accuracy)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=1000, gamma=0.01, probability=True), 0.8), 'LogReg': (LogisticRegression(C=0.0071968567300115215, class_weight='balanced',
#                    solver='liblinear'), 0.75), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.2, solver='lsqr'), 0.7833333333333333)}, 'roc_auc': {'SVC': (SVC(C=10, gamma=0.1, probability=True), 0.8), 'LogReg': (LogisticRegression(C=0.06866488450043001, class_weight='balanced',
#                    solver='newton-cg'), 0.8), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.4, solver='lsqr'), 0.7833333333333333)}, 'f1': {'SVC': (SVC(C=1000, gamma=0.01, probability=True), 0.8), 'LogReg': (LogisticRegression(C=0.0071968567300115215, class_weight='balanced',
#                    solver='liblinear'), 0.75), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.2, solver='lsqr'), 0.7833333333333333)}})
# ************************
# 13-30 : 0.6666666666666666 (accuracy)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=100, class_weight='balanced', gamma=1, kernel='linear', probability=True), 0.6333333333333333), 'LogReg': (LogisticRegression(C=0.1206792640639329, class_weight='balanced',
#                    solver='liblinear'), 0.6333333333333333), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.6666666666666666)}, 'roc_auc': {'SVC': (SVC(C=10, class_weight='balanced', gamma=1, kernel='linear', probability=True), 0.6333333333333333), 'LogReg': (LogisticRegression(C=0.022229964825261943, class_weight='balanced',
#                    solver='liblinear'), 0.6666666666666666), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.30000000000000004, solver='lsqr'), 0.6666666666666666)}, 'f1': {'SVC': (SVC(C=100, class_weight='balanced', gamma=1, kernel='linear', probability=True), 0.6333333333333333), 'LogReg': (LogisticRegression(C=0.1206792640639329, class_weight='balanced',
#                    solver='liblinear'), 0.6333333333333333), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.6666666666666666)}})
# ************************
#
# SMOTE
# ------------
# 8-12 : 0.8666666666666667 (accuracy)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=100, class_weight='balanced', gamma=1, kernel='linear', probability=True), 0.8333333333333334), 'LogReg': (LogisticRegression(C=0.001, class_weight='balanced', solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.8666666666666667)}, 'roc_auc': {'SVC': (SVC(C=0.0001, class_weight='balanced', gamma=1, probability=True), 0.8666666666666667), 'LogReg': (LogisticRegression(C=0.002329951810515372, class_weight='balanced',
#                    solver='liblinear'), 0.85), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.9, solver='lsqr'), 0.8666666666666667)}, 'f1': {'SVC': (SVC(C=100, class_weight='balanced', gamma=1, kernel='linear', probability=True), 0.8333333333333334), 'LogReg': (LogisticRegression(C=0.28117686979742307, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.6000000000000001, solver='lsqr'), 0.8666666666666667)}})
# ************************
# 8-15 : 0.8 (accuracy)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=1000, class_weight='balanced', gamma=0.01, probability=True), 0.8), 'LogReg': (LogisticRegression(C=0.0071968567300115215, class_weight='balanced',
#                    solver='liblinear'), 0.75), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.1, solver='lsqr'), 0.7833333333333333)}, 'roc_auc': {'SVC': (SVC(C=10, class_weight='balanced', gamma=0.001, probability=True), 0.8), 'LogReg': (LogisticRegression(C=0.09102981779915217, class_weight='balanced',
#                    solver='newton-cg'), 0.8), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.4, solver='lsqr'), 0.7833333333333333)}, 'f1': {'SVC': (SVC(C=1000, class_weight='balanced', gamma=0.01, probability=True), 0.8), 'LogReg': (LogisticRegression(C=0.0071968567300115215, class_weight='balanced',
#                    solver='liblinear'), 0.75), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.1, solver='lsqr'), 0.7833333333333333)}})
# ************************
# 13-30 : 0.6666666666666666 (accuracy)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=1000, class_weight='balanced', gamma=0.001, probability=True), 0.6333333333333333), 'LogReg': (LogisticRegression(C=0.09102981779915217, class_weight='balanced',
#                    solver='liblinear'), 0.6333333333333333), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.6666666666666666)}, 'roc_auc': {'SVC': (SVC(C=1000, class_weight='balanced', gamma=0.001, probability=True), 0.6333333333333333), 'LogReg': (LogisticRegression(C=0.016768329368110083, class_weight='balanced',
#                    solver='liblinear'), 0.6666666666666666), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.30000000000000004, solver='lsqr'), 0.6666666666666666)}, 'f1': {'SVC': (SVC(C=1000, class_weight='balanced', gamma=0.001, probability=True), 0.6333333333333333), 'LogReg': (LogisticRegression(C=0.09102981779915217, class_weight='balanced',
#                    solver='liblinear'), 0.6333333333333333), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.6666666666666666)}})
# ************************
#
# RU
# ------------
# 8-12 : 0.8666666666666667 (accuracy)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=1000, class_weight='balanced', gamma=0.0001, probability=True), 0.8166666666666667), 'LogReg': (LogisticRegression(C=0.49417133613238334, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.8666666666666667)}, 'roc_auc': {'SVC': (SVC(C=0.0001, class_weight='balanced', gamma=1, probability=True), 0.85), 'LogReg': (LogisticRegression(C=0.004094915062380427, class_weight='balanced',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.8666666666666667)}, 'f1': {'SVC': (SVC(C=1000, class_weight='balanced', gamma=0.0001, probability=True), 0.8166666666666667), 'LogReg': (LogisticRegression(C=0.49417133613238334, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.8666666666666667)}})
# ************************
# 8-15 : 0.8166666666666667 (accuracy)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=10, class_weight='balanced', gamma=1, kernel='linear', probability=True), 0.8166666666666667), 'LogReg': (LogisticRegression(C=0.016768329368110083, solver='liblinear'), 0.7833333333333333), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.8)}, 'roc_auc': {'SVC': (SVC(C=10, class_weight='balanced', gamma=0.1, probability=True), 0.8), 'LogReg': (LogisticRegression(C=0.09102981779915217, class_weight='balanced',
#                    solver='newton-cg'), 0.8), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.9, solver='lsqr'), 0.7666666666666667)}, 'f1': {'SVC': (SVC(C=10, class_weight='balanced', gamma=0.01, probability=True), 0.8166666666666667), 'LogReg': (LogisticRegression(C=0.49417133613238334, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.8), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.8)}})
# ************************
# 13-30 : 0.6666666666666666 (accuracy)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=0.001, class_weight='balanced', gamma=0.01, probability=True), 0.6666666666666666), 'LogReg': (LogisticRegression(C=0.09102981779915217, class_weight='balanced',
#                    solver='liblinear'), 0.6333333333333333), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.6666666666666666)}, 'roc_auc': {'SVC': (SVC(C=1, class_weight='balanced', gamma=0.01, probability=True), 0.6666666666666666), 'LogReg': (LogisticRegression(C=0.004094915062380427, solver='liblinear'), 0.6), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.7000000000000001, solver='lsqr'), 0.6666666666666666)}, 'f1': {'SVC': (SVC(C=0.001, class_weight='balanced', gamma=0.01, probability=True), 0.6666666666666666), 'LogReg': (LogisticRegression(C=0.09102981779915217, class_weight='balanced',
#                    solver='liblinear'), 0.6333333333333333), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.6666666666666666)}})
# ************************
#
# CC
# ------------
# 8-12 : 0.8666666666666667 (roc_auc)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=1, class_weight='balanced', gamma=1, kernel='linear', probability=True), 0.8333333333333334), 'LogReg': (LogisticRegression(C=0.15998587196060574, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.8, solver='lsqr'), 0.85)}, 'roc_auc': {'SVC': (SVC(C=100, class_weight='balanced', gamma=0.1, probability=True), 0.8166666666666667), 'LogReg': (LogisticRegression(C=0.3727593720314938, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.4, solver='lsqr'), 0.8666666666666667)}, 'f1': {'SVC': (SVC(C=1, class_weight='balanced', gamma=1, kernel='linear', probability=True), 0.8333333333333334), 'LogReg': (LogisticRegression(C=0.15998587196060574, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.8, solver='lsqr'), 0.85)}})
# ************************
# 8-15 : 0.8166666666666667 (accuracy)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=1, class_weight='balanced', gamma=1, probability=True), 0.8166666666666667), 'LogReg': (LogisticRegression(C=0.1206792640639329, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.7833333333333333), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.30000000000000004, solver='lsqr'), 0.7833333333333333)}, 'roc_auc': {'SVC': (SVC(C=1, class_weight='balanced', gamma=1, probability=True), 0.8166666666666667), 'LogReg': (LogisticRegression(C=0.03906939937054617, class_weight='balanced', penalty='l1',
#                    solver='liblinear'), 0.6666666666666666), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.1, solver='lsqr'), 0.7833333333333333)}, 'f1': {'SVC': (SVC(C=10, class_weight='balanced', gamma=0.01, probability=True), 0.8166666666666667), 'LogReg': (LogisticRegression(C=0.655128556859551, class_weight='balanced',
#                    solver='liblinear'), 0.8), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.30000000000000004, solver='lsqr'), 0.7833333333333333)}})
# ************************
# 13-30 : 0.6666666666666666 (accuracy)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=1, class_weight='balanced', gamma=0.01, probability=True), 0.6666666666666666), 'LogReg': (LogisticRegression(C=0.1206792640639329, class_weight='balanced',
#                    solver='liblinear'), 0.6333333333333333), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.6666666666666666)}, 'roc_auc': {'SVC': (SVC(C=0.0001, class_weight='balanced', gamma=0.1, probability=True), 0.6333333333333333), 'LogReg': (LogisticRegression(C=0.868511373751352, class_weight='balanced',
#                    solver='liblinear'), 0.65), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.6666666666666666)}, 'f1': {'SVC': (SVC(C=1, class_weight='balanced', gamma=1, kernel='linear', probability=True), 0.6333333333333333), 'LogReg': (LogisticRegression(C=0.1206792640639329, class_weight='balanced',
#                    solver='liblinear'), 0.6333333333333333), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.6666666666666666)}})
# ************************
#
# None
# ------------
# 8-12 : 0.8666666666666667 (accuracy)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=10, class_weight='balanced', gamma=0.01, probability=True), 0.8333333333333334), 'LogReg': (LogisticRegression(C=0.0017575106248547913, class_weight='balanced',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.8666666666666667)}, 'roc_auc': {'SVC': (SVC(C=0.0001, class_weight='balanced', gamma=0.1, probability=True), 0.5166666666666667), 'LogReg': (LogisticRegression(C=0.0013257113655901094, class_weight='balanced',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.9, solver='lsqr'), 0.8333333333333334)}, 'f1': {'SVC': (SVC(C=10, class_weight='balanced', gamma=0.01, probability=True), 0.8333333333333334), 'LogReg': (LogisticRegression(C=0.0017575106248547913, class_weight='balanced',
#                    solver='liblinear'), 0.8333333333333334), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.6000000000000001, solver='lsqr'), 0.85)}})
# ************************
# 8-15 : 0.8 (accuracy)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=1000, class_weight='balanced', gamma=0.01, probability=True), 0.8), 'LogReg': (LogisticRegression(C=0.0071968567300115215, class_weight='balanced',
#                    solver='liblinear'), 0.7666666666666667), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.8)}, 'roc_auc': {'SVC': (SVC(C=10, class_weight='balanced', gamma=0.001, probability=True), 0.8), 'LogReg': (LogisticRegression(C=2.023589647725158, class_weight='balanced',
#                    solver='liblinear'), 0.8), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.5, solver='lsqr'), 0.7666666666666667)}, 'f1': {'SVC': (SVC(C=1000, class_weight='balanced', gamma=0.01, probability=True), 0.8), 'LogReg': (LogisticRegression(C=0.0071968567300115215, class_weight='balanced',
#                    solver='liblinear'), 0.7666666666666667), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.8)}})
# ************************
# 13-30 : 0.6666666666666666 (accuracy)
#
# All Metrics: defaultdict(<class 'dict'>, {'accuracy': {'SVC': (SVC(C=10, class_weight='balanced', gamma=0.01, probability=True), 0.6666666666666666), 'LogReg': (LogisticRegression(C=0.15998587196060574, solver='liblinear'), 0.6333333333333333), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.6666666666666666)}, 'roc_auc': {'SVC': (SVC(C=10, class_weight='balanced', gamma=0.01, probability=True), 0.6666666666666666), 'LogReg': (LogisticRegression(C=0.016768329368110083, class_weight='balanced',
#                    solver='liblinear'), 0.6666666666666666), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.30000000000000004, solver='lsqr'), 0.6666666666666666)}, 'f1': {'SVC': (SVC(C=10, class_weight='balanced', gamma=0.01, probability=True), 0.6666666666666666), 'LogReg': (LogisticRegression(C=0.15998587196060574, solver='liblinear'), 0.6333333333333333), 'LDA': (LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr'), 0.6666666666666666)}})
# ************************

# %%
plt.figure(figsize=(8, 6))
colour_idx = 0
colours = ['purple', 'green', 'red','orange','blue']

for name, (best_band,estimator, filter_b_a, best_W) in freqBandEstimators.items():
    probs = cross_val_predict(estimator, testData_motionIntent.iloc[:,:nCols-1], testData_motionIntent.iloc[:,nCols-1], cv=5, method="predict_proba")
    probs = probs[:, 1]  # use the probability of the positive class
    true_labels = testData_motionIntent.iloc[:,nCols-1]

    # Calculate ROC curve and AUC score
    fpr, tpr, thresholds = roc_curve(true_labels, probs)
    auc_score = auc(fpr, tpr)

    # Plot ROC curve for current model
    plt.plot(fpr, tpr, color=colours[colour_idx], label= name + ' (area = %0.2f)' % auc_score)
    colour_idx += 1

    optimal_idx = np.argmax(tpr - fpr)
    optimal_threshold = thresholds[optimal_idx]
    print(f"{name} resampler optimal threshold : {optimal_threshold}")

plt.plot([0, 1], [0, 1], 'k--',alpha=0.2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# RO resampler optimal threshold : 0.5865601646113918
# SMOTE resampler optimal threshold : 0.6662058334733267
# RU resampler optimal threshold : 0.6662058334733267
# CC resampler optimal threshold : 0.4528040319053287
# None resampler optimal threshold : 0.6662058334733267

# %% [markdown]
# ### Person's Correlation Coefficient (PCC) + CSP

# %%
# #Plot distributions of channels against eachother
# # to find out if there is any sort of positive correlation
# # between channels

# import seaborn as sns
# import pandas as pd
# from sklearn.preprocessing import StandardScaler
# trialWin = np.arange(int(1.1*sRate),int(3.1*sRate))

# # #get mixed trial data from original
# trials_mixed = np.zeros(
#             (nChannels, len(eventOnsets[0]), len(trialWin)))


# for i, onset in enumerate(eventOnsets[0]):
#     trials_mixed[:,i,:] = eeg[:,onset+trialWin]

# # By augmenting the algorithm outlined in [ref: Electroencephalogram channel selection based on pearson correlation coefficient for motor imagery-brain-computer interface]
# # we can able to extract the most correlated channels in the given data prior to selecting features with the CSP algorithm.


# scaler = StandardScaler()

# # For each trial
# #We must standardize the values in each trial window for each channel (We use z-score normalization for this)
# _, nTrials, _ = trials_mixed.shape

# trialChannelCorrelations = []

# plotFirst = False #flag to check that heatmap of first trial is plotted

# for trial in range(nTrials):

#     zTrial = scaler.fit_transform(trials_mixed[:,trial,:])
#     corrMat = np.corrcoef(zTrial)

#     if not plotFirst:
#         plt.figure(figsize=(15, 16))
#         sns.heatmap(pd.DataFrame(corrMat,columns=channelNames,index=channelNames),cmap="RdYlGn",vmin=-1,vmax=1)
#         plotFirst = True

# #     # We must then calculate the correlation matrices for each trial and return the mean for each row giving, us a vector of mean values
# #     # which represents the average corellation values for a specific channel in relation to other channels.
#     channelCorrValues = {ch:corrMean for (ch,corrMean) in zip(channelNames,np.mean(corrMat,axis=1))}

# #     #Following the above referenced paper, we select the first 14 channels

#     channelCorrValues = dict(sorted(channelCorrValues.items(), key=lambda x:x[1], reverse=True)[:14])
#     trialChannelCorrelations.append(channelCorrValues)

# %%
# from collections import defaultdict

# channelOccurences = defaultdict(int)

# for dic in trialChannelCorrelations:
#     for ch, _ in dic.items():
#         channelOccurences[ch] += 1


# channelOccurences = dict(sorted(channelOccurences.items(), key=lambda x:x[1], reverse=True))

# selectedChannels = list(channelOccurences.keys())[:14]
# # #It can be seen that all selected channels are in and around the sensorimotor cortex

# selectedSet = set(selectedChannels)
# selectedIdxs = [idx for idx,ch in enumerate(channelNames) if ch in selectedSet]

# # #Plot heatmap of first trial
# plt.figure(figsize=(10, 8))
# sns.heatmap(pd.DataFrame(np.corrcoef(scaler.fit_transform(trials_mixed[selectedIdxs,0,:])),
#             columns=selectedChannels,
#             index=selectedChannels),
#             cmap="RdYlGn",
#             vmin=-1,
#             vmax=1)

# %%
# accVal = 0
# bestAccVal = 0
# bestEstimator_selected_channels = None
# for model in ["Logistic Regression","LDA","SVC"]:
#     accVal, estimator =  testClassifier(dataD,1.1,3.1,0.7,model,b=best_b,a=best_a,selectedChannels=selectedIdxs)
#     print(f"acc val for {model} is {accVal}")
#     if accVal > bestAccVal:
#         bestAccVal = accVal
#         bestEstimator_selected_channels = estimator

# bestAccVal

# %%
# bestEstimator_selected_channels

# %% [markdown]
# ### Calibration of best classifier to predict probability outputs for all time samples

# %%
evalDataG = scipy.io.loadmat("BCICIV_1eval_1000Hz_mat/BCICIV_eval_ds1g_1000Hz.mat")

# %%
bestEstimator_freq_band
# Out:
# LinearDiscriminantAnalysis(shrinkage=0.0, solver='lsqr')

# %%
idlesStateClassifier
# Out:
# LogisticRegression(C=14.563484775012444, class_weight='balanced', penalty='l1',
#                    solver='liblinear')

# %%
from sklearn.calibration import CalibratedClassifierCV

bestEstimator_freq_band = CalibratedClassifierCV(bestEstimator_freq_band,cv="prefit")
bestEstimator_freq_band.fit(testData_motionIntent.iloc[:,:nCols-1], testData_motionIntent.iloc[:,nCols-1])
# Out:
# CalibratedClassifierCV(cv='prefit',
#                        estimator=LinearDiscriminantAnalysis(shrinkage=0.0,
#                                                             solver='lsqr'))

# %%
probabilities = startRunningClassifier(evalDataG,
                                       bestEstimator_freq_band,
                                       idlesStateClassifier,motionIntentComp,
                                       idleStateComp,
                                       W_freq_band,
                                       W_idle_motionIntent,
                                       trialWinStart=0,
                                       trialWinEnd=4,
                                       b=best_b,
                                       a=best_a)

# %%
import csv

with open("output_subject_g_1000Hz.csv", "w") as f:
    wr = csv.writer(f)
    wr.writerows(probabilities)
